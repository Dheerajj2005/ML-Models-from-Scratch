# %% [markdown]
# ### Implementing Gradient Descent from Scratch

# %% [markdown]
# 1) The main goal is to find the best fit line but if there is many points and scatter all around<br> then finding best fit line would be difficult <br>
# 2) The first Option is to take different different lines and find delta x <br>
# ![image.png](attachment:image.png)
# 3) Result of this is called mean squarred error(mse) <br>
# ![image-2.png](attachment:image-2.png)
# 4) This mean squaree error is also called cost function <br>
# 5) Another way to represent mse is replacing y predicted with its value <br>
# ![image-3.png](attachment:image-3.png)
# 6) But in this method you have to make multiple best fit line and do calculation and multiple<br>
# iteration which is not the best way

# %% [markdown]
# 1) The best way is **GRADIENT DESCENT** algorithm that finds best fit line for given training data set <br>
# ![image.png](attachment:image.png)
# 2) This is the graph of m on x and b on y and mse(cost) on z if we plot all the points of 3 variable then it will form a this bowl like structure where the middle or center part have minimum error and
# ![image-2.png](attachment:image-2.png)         ![image-3.png](attachment:image-3.png)
# 3) One way is to take fixed point down to find minimum error but in this way we can miss the minimum error <br>
# ![image-4.png](attachment:image-4.png)
# 4) Another way is to go down decreasing step size along curve <br>
# ![image-5.png](attachment:image-5.png)
# 5) To find the way and decreasing step size we have to find slope at every point <br>
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### Derivative and partial derivative used in further part

# %% [markdown]
# **mse and its partial derivative**
# ![image.png](attachment:image.png)
# 1) Partail derivative gives you the direction and to find the step size we use learning rate
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# **Find the gradient descent or minimum point of vlues** <br>
# x = [1,2,3,4,5] <br>
# y = [5,7,9,11,13] <br>

# %%
import numpy as np

def gradient_descent(x, y):
    # We have to start with some value of m and b and iteration
    # Basically we are doing trial and error method and after seeing how algo perform we change the no.of iteration
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.08
    
    for i in range(iterations) :
        y_predicted = m_curr * x + b_curr
        # cost function and it should reduce in output
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        # finding m derivative and b derivative
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        # Finding m_curr and b_curr
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print("m {}, b {}, cost {}, iteration {}".format(m_curr,b_curr,cost,i))
        
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0, iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002, iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001, iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613, iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832, iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282, iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438, iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738, iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156, iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794, iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109, iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315, iteration 11
# ...

# %% [markdown]
# 1)In above code if i(iterator) start with learniing rate 0.001 we are close to 2 and 3 but if we<br> change it to 0.01 we will reach 2 and 3 <br>
# 2)**cost function should reduce if u change value** <br>
# 3)if you change it to 0.1 you will miss global minima and cost function will increase

# %% [markdown]
# 1)At 0.8 our cost function is decreasing and then we will increase our iteration to 10000 we will accurate answer <br>
# **2)when your reached your global minima ypour cost remain same**
